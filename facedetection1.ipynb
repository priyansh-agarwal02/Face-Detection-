# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import dlib

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people1.jpg')
display (image.shape)
# Out:
# (350, 590, 3)

# %%
image
# Out:
# array([[[239, 238, 234],
#         [242, 238, 233],
#         [229, 219, 212],
#         ...,
#         [252, 251, 247],
#         [252, 251, 247],
#         [252, 250, 249]],
#
#        [[241, 240, 236],
#         [243, 239, 234],
#         [232, 222, 215],
#         ...,
#         [252, 251, 247],
#         [252, 251, 247],
#         [252, 250, 249]],
#
#        [[243, 242, 238],
#         [244, 240, 235],
#         [235, 225, 218],
#         ...,
#         [253, 252, 248],
#         [253, 252, 248],
#         [253, 251, 250]],
#
#        ...,
#
#        [[105,  95,  95],
#         [ 72,  62,  62],
#         [ 49,  39,  39],
#         ...,
#         [240, 237, 229],
#         [241, 238, 230],
#         [242, 239, 231]],
#
#        [[ 79,  69,  69],
#         [ 57,  47,  47],
#         [ 47,  37,  37],
#         ...,
#         [239, 236, 228],
#         [241, 238, 230],
#         [242, 239, 231]],
#
#        [[ 61,  51,  51],
#         [ 49,  39,  39],
#         [ 49,  39,  39],
# ...

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[239 238 234]
#   [242 238 233]
#   [229 219 212]
#   ...
#   [252 251 247]
#   [252 251 247]
#   [252 250 249]]
#
#  [[241 240 236]
#   [243 239 234]
#   [232 222 215]
#   ...
#   [252 251 247]
#   [252 251 247]
#   [252 250 249]]
#
#  [[243 242 238]
#   [244 240 235]
#   [235 225 218]
#   ...
#   [253 252 248]
#   [253 252 248]
#   [253 251 250]]
#
#  ...
#
#  [[105  95  95]
#   [ 72  62  62]
#   [ 49  39  39]
#   ...
#   [240 237 229]
#   [241 238 230]
#   [242 239 231]]
#
#  [[ 79  69  69]
#   [ 57  47  47]
#   [ 47  37  37]
#   ...
#   [239 236 228]
#   [241 238 230]
#   [242 239 231]]
#
#  [[ 61  51  51]
#   [ 49  39  39]
#   [ 49  39  39]
#   ...
#   [239 236 228]
#   [241 238 230]
#   [242 239 231]]]

# %%
image = cv2.resize(image, (800, 600))

image.shape
# Out:
# (600, 800, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
display (image_gray.shape)
# Out:
# (600, 800)

# %%
face_detector = cv2.CascadeClassifier('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Cascades\\haarcascade_frontalface_default.xml')
face_detector
# Out:
# <CascadeClassifier 00000125E24A3650>

# %%
detections = face_detector.detectMultiScale(image_gray)
display (detections)
# Out:
# array([[268, 151,  85,  85]], dtype=int32)

# %%
display (len(detections))
# Out:
# 1

# %%
x=390  # X - Co ordinates 
y=323  # Y- Co ordinates 
w=56   # Face Width
h=56   # Face Height

# %%
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 1)
plt.imshow(image)
plt.show()

# %%
cv2.rectangle(image_gray, (x, y), (x + w, y + h), (100,100,150), 5)
plt.imshow(image)
plt.show()

# %%
for (x, y, w, h) in detections:
  #print (x, y, w, h)
  cv2.rectangle(image_gray, (x, y), (x + w, y + h), (0,255,255), 5)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people1.jpg')
display (image.shape)
image = cv2.resize(image, (800, 600)) # Resize image
display (image.shape) 
detections = face_detector.detectMultiScale(image)
display (detections)
# Out:
# (350, 590, 3)
# (600, 800, 3)
# array([[268, 151,  85,  85]], dtype=int32)

# %%
for (x, y, w, h) in detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (150,255,100), 5)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people1.jpg')
image = cv2.resize(image, (800, 600)) # Resize image
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 5)
plt.imshow(image)
plt.show()
# Out:
# array([[270, 153,  80,  80]], dtype=int32)

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.09)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()
# Out:
# array([[318,  79,  51,  51],
#        [589,  93,  49,  49],
#        [468,  78,  53,  53],
#        [215,  99,  51,  51],
#        [396, 105,  47,  47],
#        [139, 112,  48,  48]], dtype=int32)
# 51 51
# 49 49
# 53 53
# 51 51
# 47 47
# 48 48

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')

image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,minNeighbors=7)
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()
# Out:
# array([[470,  80,  50,  50],
#        [318,  78,  52,  52],
#        [216,  99,  51,  51],
#        [396, 106,  47,  47],
#        [139, 112,  48,  48]], dtype=int32)
# 50 50
# 52 52
# 51 51
# 47 47
# 48 48

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray, scaleFactor = 1.2,
                                            minNeighbors=7,minSize=(20,20), maxSize=(100,100))
display (detections)
for (x, y, w, h) in detections:
    print(w, h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()
# Out:
# array([[470,  80,  50,  50],
#        [318,  78,  52,  52],
#        [216,  99,  51,  51],
#        [396, 106,  47,  47],
#        [139, 112,  48,  48]], dtype=int32)
# 50 50
# 52 52
# 51 51
# 47 47
# 48 48

# %%
eye_detector= cv2.CascadeClassifier('C:\\Users\\Priyansh Agarwal\\OneDrive\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Cascades\\haarcascade_eye.xml')

display (eye_detector)
# Out:
# <CascadeClassifier 00000125E27EF470>

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people1.jpg')
display (image.shape)

image = cv2.resize(image, (1600,1000)) # Resize image
print(image.shape)
face_detections = face_detector.detectMultiScale(image, scaleFactor = 1.3, minSize = (30,30))
for (x, y, w, h) in face_detections:
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)

eye_detections = eye_detector.detectMultiScale(image, scaleFactor = 1.1, minNeighbors=10, maxSize=(60,60))

for (x, y, w, h) in eye_detections:
  print(w, h)
  cv2.rectangle(image, (x, y), (x + w, y + h), (0,0,255), 2)
plt.imshow(image)
plt.show()
# Out:
# (350, 590, 3)
# (1000, 1600, 3)
# 30 30
# 39 39
# 28 28
# 27 27
# 47 47
# 26 26
# 48 48
# 46 46
# 25 25
# 28 28
# 40 40
# 28 28

# %%
car_detector = cv2.CascadeClassifier('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Cascades\\cars.xml')

display (car_detector)
# Out:
# <CascadeClassifier 00000125E554C330>

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\car.jpg')
display (image.shape)
plt.imshow(image)
plt.show()
# Out:
# (572, 900, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = car_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=8)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()

# %%
clock_detector = cv2.CascadeClassifier('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Cascades\\clocks.xml')
display (clock_detector)
# Out:
# <CascadeClassifier 00000125E23FFF10>

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\clock.jpg')
display (image.shape)
plt.imshow(image)
plt.show()
# Out:
# (1024, 1024, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = clock_detector.detectMultiScale(image_gray, scaleFactor = 1.03, minNeighbors=1)                                      
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()

# %%
full_detector  = cv2.CascadeClassifier('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Cascades\\fullbody.xml')
display (full_detector)
# Out:
# <CascadeClassifier 00000125E41D3F90>

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people3.jpg')
display (image.shape)
plt.imshow(image)
plt.show()
# Out:
# (675, 450, 3)

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray, scaleFactor = 1.05, minNeighbors=5,
                                              minSize = (50,50)) 
for (x, y, w, h) in detections:
    cv2.rectangle(image, (x, y), (x + w, y + h), (0,255,0), 2)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')
plt.imshow(image)
plt.show()

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image, 1)

# %%
display (len(detections))
display (detections)
# Out:
# 6
# rectangles[[(217, 106) (253, 142)], [(141, 118) (184, 161)], [(472, 89) (516, 132)], [(319, 89) (362, 132)], [(401, 114) (437, 150)], [(593, 102) (629, 138)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image, (detections[0].left(), detections[0].top()), (detections[0].right(), detections[0].bottom()), (0, 255, 255), 2)
plt.imshow(image)
plt.show()
# Out:
# [(217, 106) (253, 142)]
# 217
# 106
# 253
# 142

# %%
for face in detections:
  l, t, r, b = face.left(), face.top(), face.right(), face.bottom()
  cv2.rectangle(image, (l, t), (r, b), (0, 255, 255), 2)
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Users\\Priyansh Agarwal\\OneDrive\\Desktop\\ACMEGRADE PROJECTS\\Face detection\\Data Set\\people2.jpg')
plt.imshow(image)
plt.show()
